# %% [markdown]
# **Import the relevant libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
from collections import Counter
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier
from xgboost import plot_importance
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

warnings.filterwarnings('ignore')

# %% [markdown]
# **Load the data**

# %%
raw_data = pd.read_excel(r'C:\Users\user\Downloads\a_Dataset_CreditScoring.xlsx')

# %%
raw_data.head()
# Out:
#    TARGET    ID  DerogCnt  CollectCnt  BanruptcyInd  InqCnt06  InqTimeLast  \
# 0       1   582         3           3             0         4          0.0
# 1       1   662        15           9             0         3          1.0
# 2       1   805         0           0             0         1          5.0
# 3       1  1175         8           5             0         6          1.0
# 4       1  1373         3           1             0         9          0.0
#
#    InqFinanceCnt24  TLTimeFirst  TLTimeLast  ...  TL50UtilCnt  TLBalHCPct  \
# 0                5          117          27  ...          3.0      0.9179
# 1                3           14          14  ...          1.0      0.8000
# 2                1          354           7  ...          5.0      0.3552
# 3               10           16           4  ...          3.0      0.9127
# 4                8          130          52  ...          1.0      1.2511
#
# ...

# %% [markdown]
# **Data preparation**

# %%
#show count of rows and columns
raw_data.shape
# Out:
# (3000, 30)

# %%
#make a copy of the raw data
data = raw_data.copy()
data
# Out:
#       TARGET      ID  DerogCnt  CollectCnt  BanruptcyInd  InqCnt06  \
# 0          1     582         3           3             0         4
# 1          1     662        15           9             0         3
# 2          1     805         0           0             0         1
# 3          1    1175         8           5             0         6
# 4          1    1373         3           1             0         9
# ...      ...     ...       ...         ...           ...       ...
# 2995       0  126441         0           0             0         2
# 2996       0  126448         0           0             0         0
# 2997       0  126465         1           1             0         8
# 2998       0  126487         4           4             0         2
# 2999       0  126503         2           1             1         0
#
#       InqTimeLast  InqFinanceCnt24  TLTimeFirst  TLTimeLast  ...  TL50UtilCnt  \
# 0             0.0                5          117          27  ...          3.0
# ...

# %%
#drop the customer ID column
data = data.drop('ID', axis=1)
data
# Out:
#       TARGET  DerogCnt  CollectCnt  BanruptcyInd  InqCnt06  InqTimeLast  \
# 0          1         3           3             0         4          0.0
# 1          1        15           9             0         3          1.0
# 2          1         0           0             0         1          5.0
# 3          1         8           5             0         6          1.0
# 4          1         3           1             0         9          0.0
# ...      ...       ...         ...           ...       ...          ...
# 2995       0         0           0             0         2          0.0
# 2996       0         0           0             0         0          NaN
# 2997       0         1           1             0         8          0.0
# 2998       0         4           4             0         2          3.0
# 2999       0         2           1             1         0         18.0
#
#       InqFinanceCnt24  TLTimeFirst  TLTimeLast  TLCnt03  ...  TL50UtilCnt  \
# ...

# %%
#explore missing values
data.isnull().sum()
# Out:
# TARGET               0
# DerogCnt             0
# CollectCnt           0
# BanruptcyInd         0
# InqCnt06             0
# InqTimeLast        188
# InqFinanceCnt24      0
# TLTimeFirst          0
# TLTimeLast           0
# TLCnt03              0
# TLCnt12              0
# TLCnt24              0
# TLCnt                3
# TLSum               40
# TLMaxSum            40
# TLSatCnt             4
# TLDel60Cnt           0
# TLBadCnt24           0
# TL75UtilCnt         99
# TL50UtilCnt         99
# TLBalHCPct          41
# TLSatPct             4
# TLDel3060Cnt24       0
# TLDel90Cnt24         0
# TLDel60CntAll        0
# TLOpenPct            3
# TLBadDerogCnt        0
# TLDel60Cnt24         0
# TLOpen24Pct          3
# dtype: int64

# %%
#fill missing values with mean
data = data.fillna(data.mean())

# %%
#explore missing values after fix
data.isnull().sum()
# Out:
# TARGET             0
# DerogCnt           0
# CollectCnt         0
# BanruptcyInd       0
# InqCnt06           0
# InqTimeLast        0
# InqFinanceCnt24    0
# TLTimeFirst        0
# TLTimeLast         0
# TLCnt03            0
# TLCnt12            0
# TLCnt24            0
# TLCnt              0
# TLSum              0
# TLMaxSum           0
# TLSatCnt           0
# TLDel60Cnt         0
# TLBadCnt24         0
# TL75UtilCnt        0
# TL50UtilCnt        0
# TLBalHCPct         0
# TLSatPct           0
# TLDel3060Cnt24     0
# TLDel90Cnt24       0
# TLDel60CntAll      0
# TLOpenPct          0
# TLBadDerogCnt      0
# TLDel60Cnt24       0
# TLOpen24Pct        0
# dtype: int64

# %%
#count of good loans(0) and bad loans(1)
#the count shows there is class imbalance
data['TARGET'].value_counts()
# Out:
# TARGET
# 0    2500
# 1     500
# Name: count, dtype: int64

# %%
#data summary across 0 & 1
#here i grouped the data by the target and checked the mean of each feature
#this helps to spot trends e.g do bad loan customers have lower income? or do they have more debt?
#this is useful for early feature selection and understanding model behaviour
data.groupby('TARGET').mean()
# Out:
#         DerogCnt  CollectCnt  BanruptcyInd  InqCnt06  InqTimeLast  \
# TARGET
# 0         1.3224      0.7664        0.1492    2.9424     3.174638
# 1         1.9680      1.3100        0.1740    3.9380     2.775459
#
#         InqFinanceCnt24  TLTimeFirst  TLTimeLast  TLCnt03  TLCnt12  ...  \
# TARGET                                                              ...
# 0                3.2896      173.002      11.650   0.2844    1.832  ...
# 1                4.8820      155.672      12.992   0.2280    1.768  ...
#
#         TL50UtilCnt  TLBalHCPct  TLSatPct  TLDel3060Cnt24  TLDel90Cnt24  \
# TARGET
# 0          3.986711    0.628177  0.544963          0.6044        0.6624
# 1          4.533870    0.748185  0.385173          1.3340        1.5760
#
#         TLDel60CntAll  TLOpenPct  TLBadDerogCnt  TLDel60Cnt24  TLOpen24Pct
# TARGET
# 0              2.2236   0.502376          1.180        0.8648     0.556867
# 1              4.0140   0.465127          2.554        2.0860     0.600978
#
# ...

# %%
data.head()
# Out:
#    TARGET  DerogCnt  CollectCnt  BanruptcyInd  InqCnt06  InqTimeLast  \
# 0       1         3           3             0         4          0.0
# 1       1        15           9             0         3          1.0
# 2       1         0           0             0         1          5.0
# 3       1         8           5             0         6          1.0
# 4       1         3           1             0         9          0.0
#
#    InqFinanceCnt24  TLTimeFirst  TLTimeLast  TLCnt03  ...  TL50UtilCnt  \
# 0                5          117          27        0  ...          3.0
# 1                3           14          14        0  ...          1.0
# 2                1          354           7        0  ...          5.0
# 3               10           16           4        0  ...          3.0
# 4                8          130          52        0  ...          1.0
#
#    TLBalHCPct  TLSatPct  TLDel3060Cnt24  TLDel90Cnt24  TLDel60CntAll  \
# ...

# %% [markdown]
# **Declare the dependent and independent variable**

# %%
y = data['TARGET']
x = data.drop('TARGET', axis=1)

# %%
#scale the data
scaler = StandardScaler()

# %%
scaler.fit(x)
# Out:
# StandardScaler()

# %%
#get the standardized inputs
x_scaled = scaler.transform(x)

# %% [markdown]
# **Split data into test and training**

# %%
x_scaled_train, x_scaled_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# **Handle Class Imbalance**

# %% [markdown]
# **Create a SMOTE object**

# %%
smote = SMOTE(random_state=42)

# %%
# Apply SMOTE to the training features and labels
x_scaled_train_sm, y_train_sm = smote.fit_resample(x_scaled_train, y_train)

# %% [markdown]
# **Check the new class balance**

# %%
print("Before SMOTE:", Counter(y_train))
print("After SMOTE:", Counter(y_train_sm))
# Out:
# Before SMOTE: Counter({0: 2000, 1: 400})
# After SMOTE: Counter({0: 2000, 1: 2000})

# %% [markdown]
# **XGBoost**

# %%
#initialize xgboost with imbalance handling
xgb_model = XGBClassifier(
    scale_pos_weight=2,  # Helps with imbalance
    use_label_encoder=False, 
    eval_metric='logloss',
    random_state=42
)

# %%
#fit the model
xgb_model.fit(x_scaled_train_sm, y_train_sm)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# **Make prediction on the test set**

# %%
y_pred_xgb = xgb_model.predict(x_scaled_test)

# %% [markdown]
# **Threshold tuning**

# %%
#get predicted probabilities for class 0 and 1
y_probs = xgb_model.predict_proba(x_scaled_test)

# %%
# Save both columns in a DataFrame
df_prob = pd.DataFrame(y_probs, columns=["Prob_Class_0", "Prob_Class_1"])

# %%
#set a lower threshold
y_pred_thresh = (df_prob["Prob_Class_1"] > 0.25).astype(int)

# %%
y_pred_thresh.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Prob_Class_1, dtype: int32

# %% [markdown]
# **Model performance**

# %%
#confusion matrix
cm = confusion_matrix(y_test, y_pred_thresh)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[437  63]
#  [ 52  48]]

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Pred 0', 'Pred 1'], yticklabels=['Actual 0', 'Actual 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#accuracy score
print(accuracy_score(y_test, y_pred_thresh))
# Out:
# 0.8083333333333333

# %% [markdown]
# **Classification report**

# %%
# Generate the report as a dictionary
report_dict = classification_report(y_test, y_pred_thresh, output_dict=True, target_names=['good loan', 'bad loan'])

# Convert to a DataFrame
report_df = pd.DataFrame(report_dict).transpose()

# Round for cleaner display
report_df = report_df.round(3)

# Show the table
report_df
# Out:
#               precision  recall  f1-score  support
# good loan         0.894   0.874     0.884  500.000
# bad loan          0.432   0.480     0.455  100.000
# accuracy          0.808   0.808     0.808    0.808
# macro avg         0.663   0.677     0.669  600.000
# weighted avg      0.817   0.808     0.812  600.000

# %% [markdown]
# **Writing output file**

# %%
#Create DataFrames
df_actual = pd.DataFrame(y_test.values, columns=["Actual"])
df_prob = pd.DataFrame(y_probs, columns=["Prob_Class_0", "Prob_Class_1"])
df_pred = pd.DataFrame(y_pred_thresh.values, columns=["Predicted"])

# %%
# Concatenate into final result
df_output = pd.concat([df_actual.reset_index(drop=True), df_prob, df_pred], axis=1)

# %%
# Preview
df_output.head()
# Out:
#    Actual  Prob_Class_0  Prob_Class_1  Predicted
# 0       1      0.605660      0.394340          1
# 1       0      0.998685      0.001315          0
# 2       0      0.998325      0.001675          0
# 3       0      0.985886      0.014114          0
# 4       0      0.981745      0.018255          0

# %%
print(len(df_actual), len(df_prob), len(df_pred))  # Should all match
print(df_actual.index[:5], df_pred.index[:5])      # Should both be RangeIndex(start=0, ...)
# Out:
# 600 600 600
# RangeIndex(start=0, stop=5, step=1) RangeIndex(start=0, stop=5, step=1)

# %%
# Save as CSV and Excel
df_output.to_csv("credit_model_predictions_threshold_025.csv", index=False, encoding='utf-8')
df_output.to_excel("credit_model_predictions_threshold_025.xlsx", index=False)

# %% [markdown]
# **Plot the Top 10 Features**
